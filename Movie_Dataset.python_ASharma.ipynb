# %% [markdown]
# # Project Title: TMDB Movie Data Analysis

# %% [markdown]
# Introduction:
#
# The Movie Data dataset used in this analysis is a comprehensive collection of information about a wide range of movies from various genres, title,runtime,popularity,production companies,Budget,Revenue,and so on which helped us to Analyze and Visualize the data.It provides valuable insights into the world of cinema. This dataset has 4803 x rows and 20 x columns.Checked for duplicate value if any but didn't find such entry.

# %% [markdown]
# - Added few steps and tasks to give more and clear analysis for the conclusion

# %% [markdown]
# Task 1: Load the movie dataset in the Python Notebook. Display the numbers of rows and columns in the dataset. Display the titles and genres of the first 50 movies from the dataset.

# %%
import pandas as pd
import numpy as np
import statistics as st
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading Movie dataset
movie_df = pd.read_csv('DS1_C7_Data_Analysis_Using_Python_Dataset_CP.csv')
display(movie_df)

# Dispalying the number of rows and columns
print('Number of rows and coloumns :')
print('..............................................')
print(movie_df.shape)
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
print(movie_df.dtypes) #datatypes
# Out:
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# title                    object
# vote_average            float64
# vote_count                int64
# dtype: object

# %%
# Checking if any duplicate enrty in the dataframe
movie_df[movie_df.duplicated(keep=False)]

# shows 0 columns and rows,means no duplicate enrty
# Out:
# Empty DataFrame
# Columns: [budget, genres, homepage, id, keywords, original_language, original_title, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, vote_average, vote_count]
# Index: []

# %%
# Displaying the titles and generes of the first 50 movies
#print('Genres')
#movie_df.genres[0:50]

dis = movie_df.sort_values(by=['genres','title'],ascending=False).head(50)
y = dis[['genres','title','budget','revenue']]
display(y)
# Out:
#                                    genres  \
# 4520  [{"id": 99, "name": "Documentary"}]
# 1730  [{"id": 99, "name": "Documentary"}]
# 4366  [{"id": 99, "name": "Documentary"}]
# 3751  [{"id": 99, "name": "Documentary"}]
# 4250  [{"id": 99, "name": "Documentary"}]
# 4593  [{"id": 99, "name": "Documentary"}]
# 4712  [{"id": 99, "name": "Documentary"}]
# 4140  [{"id": 99, "name": "Documentary"}]
# 3855  [{"id": 99, "name": "Documentary"}]
# 4689  [{"id": 99, "name": "Documentary"}]
# 3768  [{"id": 99, "name": "Documentary"}]
# 4536  [{"id": 99, "name": "Documentary"}]
# 4759  [{"id": 99, "name": "Documentary"}]
# 4706  [{"id": 99, "name": "Documentary"}]
# 4508  [{"id": 99, "name": "Documentary"}]
# 4491  [{"id": 99, "name": "Documentary"}]
# 4227  [{"id": 99, "name": "Documentary"}]
# 4685  [{"id": 99, "name": "Documentary"}]
# 4381  [{"id": 99, "name": "Documentary"}]
# 4382  [{"id": 99, "name": "Documentary"}]
# 3646  [{"id": 99, "name": "Documentary"}]
# ...

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# Task 2: Identify the columns that have null values and perform the null value treatment. (Choose the imputation method based on the type of data in the columns of interest.)

# %% [markdown]
# Data Exploration and Imputation:
#
# Load the data into a Pandas DataFrame. Check the first few rows to understand the structure of the data. Handled the missing values by either removing rows of any missing data or imputing values.It has some missing values and filled them by using the imputation method by Mean(). Checked for any duplicate values but there was no such entries. Also filtered the Budget and Revenue value where the value was 0 so we can have clean and clear analysis.

# %%
all_cols = ['budget','genres','homepage','id','keywords','original_language',
            'original_title','overview','popularity','production_companies',
            'production_countries','release_date','revenue','runtime',
            'spoken_languages','status','tagline','title','vote_average','vote_count']

movie_df = movie_df[all_cols]
movie_df
# Checking the null values
movie_df.isnull().sum()
# as we can clearly see here that some columns contains missing values
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    2
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %%
# Converting release_date column datatype into datetime datatype
movie_df['release_date'] = pd.to_datetime(movie_df['release_date'])
print(movie_df.dtypes)
# Out:
# budget                           int64
# genres                          object
# homepage                        object
# id                               int64
# keywords                        object
# original_language               object
# original_title                  object
# overview                        object
# popularity                     float64
# production_companies            object
# production_countries            object
# release_date            datetime64[ns]
# revenue                          int64
# runtime                        float64
# spoken_languages                object
# status                          object
# tagline                         object
# title                           object
# vote_average                   float64
# vote_count                       int64
# dtype: object

# %%
# Imputing the missing values by using mean
missing_val =['homepage','overview','release_date','runtime','tagline']

movie_df[missing_val] = movie_df[missing_val].fillna(movie_df[missing_val].mean())

# %%
movie_df.isna().sum()
# As we can see the data type: float where values were missing ,filled the gaps but the datatype:object is not changed
# Out:
# budget                     0
# genres                     0
# homepage                3091
# id                         0
# keywords                   0
# original_language          0
# original_title             0
# overview                   3
# popularity                 0
# production_companies       0
# production_countries       0
# release_date               1
# revenue                    0
# runtime                    0
# spoken_languages           0
# status                     0
# tagline                  844
# title                      0
# vote_average               0
# vote_count                 0
# dtype: int64

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# Task 3: Display the movie categories that have a budget greater than $220,000.

# %%
movie_df.head(0)
# Out:
# Empty DataFrame
# Columns: [budget, genres, homepage, id, keywords, original_language, original_title, overview, popularity, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, vote_average, vote_count]
# Index: []

# %%
Budget = movie_df[movie_df.budget >= 220000]
budget = Budget[['budget','revenue']]#.head(50)
print(budget.count())
display(budget)
# Out:
# budget     3184
# revenue    3184
# dtype: int64
#          budget     revenue
# 0     237000000  2787965087
# 1     300000000   961000000
# 2     245000000   880674609
# 3     250000000  1084939099
# 4     260000000   284139100
# ...         ...         ...
# 4666     225000      111300
# 4670     400000   100000000
# 4720    8500000    15861566
# 4758    4000000      600896
# 4798     220000     2040920
#
# [3184 rows x 2 columns]

# %% [markdown]
# Task 4: Display the movie categories where the revenue is greater than $961,000,000.

# %%
Revenue = movie_df[movie_df.revenue > 961000000]
revenue = Revenue[['budget','revenue']]
print(revenue.count())
display(revenue)
# Out:
# budget     24
# revenue    24
# dtype: int64
#         budget     revenue
# 0    237000000  2787965087
# 3    250000000  1084939099
# 7    280000000  1405403694
# 12   200000000  1065659812
# 16   220000000  1519557910
# 17   380000000  1045713802
# 25   200000000  1845034188
# 26   250000000  1153304495
# 28   150000000  1513528810
# 29   200000000  1108561013
# 31   200000000  1215439994
# 32   200000000  1025491110
# 36   210000000  1091405097
# 42   200000000  1066969703
# 44   190000000  1506249360
# 52   195000000  1123746996
# 65   185000000  1004558444
# 78   175000000   966550600
# 98   250000000  1021103568
# 124  150000000  1274219009
# 197  125000000   976475550
# 329   94000000  1118888979
# 506   76000000   970761885
# 546   74000000  1156730962

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# Task 5: In the dataset, there are some movies for which the budget and revenue columns have the value 0, which means
#     unknown values. Remove the rows withvalue 0 from both the budget and revenue columns.

# %%
temp_df = movie_df.copy()
temp_df.shape
# Out:
# (4803, 20)

# %%
# showing the zero values for budget and revenue
print('Bugdet with 0 value.......................................')
display(movie_df[(movie_df.budget == 0)])
print('Revenue with 0 value...........................................')
display(movie_df[movie_df.revenue == 0])
# Out:
# Bugdet with 0 value.......................................
#       budget                                             genres  \
# 265        0  [{"id": 35, "name": "Comedy"}, {"id": 14, "nam...
# 321        0                     [{"id": 35, "name": "Comedy"}]
# 359        0  [{"id": 12, "name": "Adventure"}, {"id": 16, "...
# 406        0  [{"id": 18, "name": "Drama"}, {"id": 16, "name...
# 409        0  [{"id": 18, "name": "Drama"}, {"id": 10402, "n...
# ...      ...                                                ...
# 4795       0                      [{"id": 18, "name": "Drama"}]
# 4797       0  [{"id": 10769, "name": "Foreign"}, {"id": 53, ...
# 4800       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801       0                                                 []
# 4802       0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 265                                                 NaN   10588
# ...

# %%
# removing 0's from both the budget and revenue by using ~(tilde)

condition_1 = (movie_df['budget'] == 0)
condition_2 = (movie_df['revenue'] == 0)

combined_condition = condition_1 | condition_2
movie_df = movie_df[~combined_condition] # using ~ tilde func to remove zeros from bugdet and revenue column
movie_df
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4773      27000                     [{"id": 35, "name": "Comedy"}]
# 4788      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 4792      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 4796       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                           homepage      id  \
# 0                      http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# Task 6: List the top 10 movies with the highest revenues and the
# top 10 movies with the least budget.

# %%
# sorting value by revenue and budget 
print('.........Top 10 movies with the highest revenues...........')
highest = movie_df.sort_values(by =['revenue'],ascending = False)#.head(10)
highest_10 = highest[['budget','revenue']].head(10)
display(highest_10)
print('...............Top 10 movies with the least budget.........')
least = movie_df.sort_values(by ='budget',ascending = True)#.head(10)
least_10 = least[['budget','revenue']].head(10)
display(least_10)
# Out:
# .........Top 10 movies with the highest revenues...........
#         budget     revenue
# 0    237000000  2787965087
# 25   200000000  1845034188
# 16   220000000  1519557910
# 28   150000000  1513528810
# 44   190000000  1506249360
# 7    280000000  1405403694
# 124  150000000  1274219009
# 31   200000000  1215439994
# 546   74000000  1156730962
# 26   250000000  1153304495
# ...............Top 10 movies with the least budget.........
#       budget   revenue
# 4238       1   8500000
# 3611       4        25
# 3372       7         5
# 3419       7         7
# 4608       8        16
# 3131      10        11
# 3137      10  10000000
# 2933      11        11
# 1912      25        13
# 1771      28        14

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# Task 7: How are the popularities of movies related to the movie budgets? Are they correlated or totally uncorrelated with each other? Write the interpretation of your analysis.

# %%
# Coorelation between the budget and the popularity of 50 movies
pb_corr = dis['popularity'].corr(dis['budget'])
print('Result :',pb_corr)
# Out:
# Result : 0.6314498089634972

# %%
plt.scatter(dis['popularity'],dis['budget'],color = 'orange')
plt.title('Popularity vs Budget')
#plt.xlim(0,300)
#plt.ylim(1,35)
plt.xlabel("R = " + str(pb_corr))
# Out:
# Text(0.5, 0, 'R = 0.6314498089634972')

# %% [markdown]
# According to the result of correlation between popularity and budget which is positive but far from 1 means if they are increasing the budget will not surely result in increase the popularity among the people to watch the movie.
# So, they are actually not showing a good correlation

# %% [raw]
# Showing the comaparison of Popularity and Runtime

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans

x = movie_df[['popularity', 'runtime']]
x
# Out:
#       popularity  runtime
# 0     150.437577    162.0
# 1     139.082615    169.0
# 2     107.376788    148.0
# 3     112.312950    165.0
# 4      43.926995    132.0
# ...          ...      ...
# 4773   19.748658     92.0
# 4788    4.553644     93.0
# 4792    0.212443    111.0
# 4796   23.307949     77.0
# 4798   14.269792     81.0
#
# [3229 rows x 2 columns]

# %%
kmeans = KMeans(n_clusters=2)  # choose the number of clusters
movie_df['cluster'] = kmeans.fit_predict(x)
plt.figure(figsize=(10,5))

# Plot data points based on cluster assignments
for cluster_num in movie_df['cluster'].unique():
    cluster_data = movie_df[movie_df['cluster'] == cluster_num]
    plt.scatter(cluster_data['popularity'], cluster_data['runtime'], label=f'Cluster {cluster_num}')

# Add labels and legend
plt.xlabel('Popularity')
plt.ylabel('Runtime')
plt.legend()

plt.show()

# %% [markdown]
# It might observe that, on average, longer runtime movies tend to have higher popularity, and vice versa.

# %%
import seaborn as sns
sns.heatmap(movie_df.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# You can see the correlation of whole dataset between each other with the help of chart and heatmap,it can gives us better understand of Dataset with there relations between each other that how strongly they can support ecah other in terms of profit and loss.

# %%
# Analysing the relation between the popularity,vote_average,budget and revenue
dis = movie_df.sort_values(by=['vote_average','popularity'],ascending=False).head(50)
z = dis[['popularity','budget','vote_average','revenue','budget']]
display(z)
# Out:
#       popularity     budget  vote_average     revenue     budget
# 1881  136.747729   25000000           8.5    28341469   25000000
# 2970    0.037073   10500000           8.5      123509   10500000
# 3337  143.659698    6000000           8.4   245066411    6000000
# 3865  192.528841    3300000           8.3    13092000    3300000
# 662   146.757391   63000000           8.3   100853753   63000000
# 3232  121.463076    8000000           8.3   213928762    8000000
# 2294  118.968562   15000000           8.3   274925095   15000000
# 2731  105.792936   13000000           8.3    47542841   13000000
# 1818  104.469351   22000000           8.3   321365567   22000000
# 65    187.322927  185000000           8.2  1004558444  185000000
# 809   138.133331   55000000           8.2   677945399   55000000
# 3719  127.525581    3000000           8.2   108981275    3000000
# 690   103.698022   60000000           8.2   284600000   60000000
# ...

# %% [markdown]
# Ratings are often subjective and depend on individual preferences.Two movies with similar popularity might receive different ratings due to varying tastes and opinions.Even in the table it results low populairty getting high vote average which results in low revenue output with high budget.Also,different genres may attract distinct audiences. A movie might be popular among a certain demographic but receive mixed ratings across a broader audience.

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# Task 8: Identify and display the names of all production companies along with the number of times they appear in the dataset.

# %%
# Using a unique() method to findout the repeating names of prod. companies
pro_com = movie_df.production_companies.unique()
print('Names :')
display(pro_com)
print('...................................................................')
# number of times
number = movie_df.production_companies.nunique()
print('Number of times :',number)

# %% [markdown]
# ------------------------------------------------------------------------------------------------

# %% [markdown]
# Task 9: Display the names of the top 25 production companies based on the number of movies they have produced in descending order of the number of movies produced.

# %%
# Group the DataFrame by production companies and count the number of movies produced by each.
company_movie_counts = movie_df['production_companies'].value_counts()

# Get the top 25 production companies based on the number of movies produced.
top_25_companies = company_movie_counts.head(25)

# Display the top 25 production companies in descending order.
display(top_25_companies)

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# Task 10: Sort the data in descending order based on revenue and filter the top 500 movies. Find the measures of central tendency for the following columns using the filtered data:
#
# 1.Budget
# 2.Revenue
# 3.Runtime
#
# Perform outlier analysis for the above three columns using box plots.

# %% [markdown]
# Summary Statistics:
#
# For the analysis use of statistics is very helpful in context of Central Tendencies. It can shows us the outliers with calculation of Mean and Median which shows if Mean is higher than Median.
# Analysis are made on the filtered data of top 500 movies which shows the outlier of budget , revenue and runtime. It can clearly be seen in the calculation where mean is greater than the median shows outlier. Here I am comparing top_500_movies and the least_500_movies to get the better understanding of budget and revenue

# %%
#sorting data in descending order
sorted_movies = movie_df.sort_values(by = 'revenue',ascending = False)
# Filter the top 500 movies.
top_500_movies = sorted_movies[['budget','revenue','runtime']].head(500)
display(top_500_movies)
# Out:
#          budget     revenue  runtime
# 0     237000000  2787965087    162.0
# 25    200000000  1845034188    194.0
# 16    220000000  1519557910    143.0
# 28    150000000  1513528810    124.0
# 44    190000000  1506249360    137.0
# ...         ...         ...      ...
# 397    85000000   219103655    121.0
# 1744   30000000   219076518    129.0
# 698    70000000   218613188     99.0
# 717    60000000   218340595    130.0
# 714    65000000   217764291    120.0
#
# [500 rows x 3 columns]

# %% [markdown]
# For instance, in a dataset, most the movies might have moderate budget,revenue and runtime , but a few extremely high movies could significantly raise the mean. The mean and median can provide insights into the shape of the data distribution. If the mean is substantially greater than the median, it suggests that there are relatively few very high values in the dataset as seen in the calculation above in both Top and Least movies that shows the difference of Good performing movies and the bad performing movies.

# %%
# Calculate the measures of central tendency
budget_mean = top_500_movies['budget'].mean()
budget_median = top_500_movies['budget'].median()
budget_mode = top_500_movies['budget'].mode().values[0]

revenue_mean = top_500_movies['revenue'].mean()
revenue_median = top_500_movies['revenue'].median()
revenue_mode = top_500_movies['revenue'].mode().values[0]

runtime_mean = top_500_movies['runtime'].mean()
runtime_median = top_500_movies['runtime'].median()
runtime_mode = top_500_movies['runtime'].mode().values[0]

# Display the results
print("Measures of Central Tendency for Budget:")
print(f"Mean: {budget_mean}")
print(f"Median: {budget_median}")
print(f"Mode: {budget_mode}")
print(f"..........................................................")

print("\nMeasures of Central Tendency for Revenue:")
print(f"Mean: {revenue_mean}")
print(f"Median: {revenue_median}")
print(f"Mode: {revenue_mode}")
print(f"..........................................................")

print("\nMeasures of Central Tendency for Runtime:")
print(f"Mean: {runtime_mean}")
print(f"Median: {runtime_median}")
print(f"Mode: {runtime_mode}")
# Out:
# Measures of Central Tendency for Budget:
# Mean: 103193736.0
# Median: 95000000.0
# Mode: 150000000
# ..........................................................
#
# Measures of Central Tendency for Revenue:
# Mean: 458577595.062
# Median: 363001569.5
# Mode: 217764291
# ..........................................................
#
# Measures of Central Tendency for Runtime:
# Mean: 118.72
# Median: 116.0
# Mode: 115.0

# %%
# Plotting bar graphs for budget, revenue, and runtime
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(5, 10))

# Bar graph for budget
axes[0].bar(top_500_movies.index, top_500_movies['budget'], color='blue', alpha=0.7)
axes[0].set_title('Budget for Top 500 Movies')

# Bar graph for revenue
axes[1].bar(top_500_movies.index, top_500_movies['revenue'], color='green', alpha=0.7)
axes[1].set_title('Revenue for Top 500 Movies')

# Bar graph for runtime
axes[2].bar(top_500_movies.index, top_500_movies['runtime'], color='orange', alpha=0.7)
axes[2].set_title('Runtime for Top 500 Movies')

# Set common labels and layout
for ax in axes:
    ax.set_xlabel('Movie Index')
    ax.set_ylabel('Amount')
    ax.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Here in the bar graphs, movie_df sorted out according to top 500 good performing movies on the bases of Budget,Revenue and Runtime. It seems that according to the budget movies are giving revenue and the runtime is also high.

# %%
#sorting data in ascending order
sorted_movies = movie_df.sort_values(by = 'revenue',ascending = True)
# Filter the top 500 movies.
last_500_movies = sorted_movies[['budget','revenue','runtime']].head(500)
display(last_500_movies)
# Out:
#         budget  revenue  runtime
# 3372         7        5     90.0
# 3419         7        7     82.0
# 3875   2000000        7     92.0
# 2933        11       11    145.0
# 3131        10       11     85.0
# ...        ...      ...      ...
# 3635   5000000  8203235    101.0
# 3164   7000000  8220215    110.0
# 3265   8000000  8279017     92.0
# 1734  28000000  8345056     86.0
# 2881  12400000  8371085    142.0
#
# [500 rows x 3 columns]

# %%
# Calculate the measures of central tendency
budget_mean = last_500_movies['budget'].mean()
budget_median = last_500_movies['budget'].median()
budget_mode = last_500_movies['budget'].mode().values[0]

revenue_mean = last_500_movies['revenue'].mean()
revenue_median = last_500_movies['revenue'].median()
revenue_mode = last_500_movies['revenue'].mode().values[0]

runtime_mean = last_500_movies['runtime'].mean()
runtime_median = last_500_movies['runtime'].median()
runtime_mode = last_500_movies['runtime'].mode().values[0]

# Display the results
print("Measures of Central Tendency for Budget:")
print(f"Mean: {budget_mean}")
print(f"Median: {budget_median}")
print(f"Mode: {budget_mode}")
print(f"..........................................................")

print("\nMeasures of Central Tendency for Revenue:")
print(f"Mean: {revenue_mean}")
print(f"Median: {revenue_median}")
print(f"Mode: {revenue_mode}")
print(f"..........................................................")

print("\nMeasures of Central Tendency for Runtime:")
print(f"Mean: {runtime_mean}")
print(f"Median: {runtime_median}")
print(f"Mode: {runtime_mode}")
# Out:
# Measures of Central Tendency for Budget:
# Mean: 9481473.724
# Median: 5650000.0
# Mode: 2000000
# ..........................................................
#
# Measures of Central Tendency for Revenue:
# Mean: 3201535.694
# Median: 2824471.0
# Mode: 8000000
# ..........................................................
#
# Measures of Central Tendency for Runtime:
# Mean: 104.72
# Median: 101.0
# Mode: 98.0

# %%
# Plotting bar graphs for budget, revenue, and runtime
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(5, 10))

# Bar graph for budget
axes[0].bar(last_500_movies.index, last_500_movies['budget'], color='blue', alpha=0.7)
axes[0].set_title('Budget for Last 500 Movies')

# Bar graph for revenue
axes[1].bar(last_500_movies.index, last_500_movies['revenue'], color='green', alpha=0.7)
axes[1].set_title('Revenue for Last 500 Movies')

# Bar graph for runtime
axes[2].bar(last_500_movies.index, last_500_movies['runtime'], color='orange', alpha=0.7)
axes[2].set_title('Runtime for Last 500 Movies')

# Set labels and layout
for ax in axes:
    ax.set_xlabel('Movie Index')
    ax.set_ylabel('Amount')
    ax.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# The movies with the least revenue are low-budget productions but some with low budget production they have high revenue movies as well,and their shorter runtimes might be a consequence of limited resources.Different movie genres have different typical runtimes.This dataset includes a variety of generes,which can affect the overall runtime.

# %%
# Create box plots for 'Budget', 'Revenue', and 'Runtime'
plt.figure(figsize=(12, 6))
plt.subplot(131)
sns.boxplot(data=sorted_movies, y='budget')
plt.title("Box Plot for Budget")

plt.subplot(132)
sns.boxplot(data=sorted_movies, y='revenue')
plt.title("Box Plot for Revenue")

plt.subplot(133)
sns.boxplot(data=sorted_movies, y='runtime')
plt.title("Box Plot for Runtime")


plt.tight_layout()
plt.show()

# %% [markdown]
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# Task 11: Identify and display the names of the movies along with their run times for those movies that have above average runtime, using the data from the previous task.

# %%
# Assuming 'data' is your DataFrame with movie data
# Calculate the average runtime
average_runtime = top_500_movies['runtime'].mean()

# Select movies with runtimes above the average
above_average_movies = top_500_movies[top_500_movies['runtime'] > average_runtime]

# Sort the result in ascending order by runtime
above_average_movies_sorted = above_average_movies.sort_values(by='runtime').head(50)

# Display the names and runtimes of above-average movies
movie_names_runtimes = above_average_movies_sorted[['revenue','budget','runtime']]
display(movie_names_runtimes)
# Out:
#          revenue     budget  runtime
# 249    295238201  110000000    119.0
# 2667   320145693   14000000    119.0
# 638    250821495   65000000    119.0
# 2018   369884651   23000000    119.0
# 278    362211740  100000000    119.0
# 245    333011068  110000000    119.0
# 2668   463000000   14000000    119.0
# 1987   234710455   24000000    119.0
# 252    227817248  120000000    119.0
# 2091   272742922   19000000    119.0
# 714    217764291   65000000    120.0
# 209    276572938  130000000    120.0
# 248    478207520  110000000    120.0
# 1161   224920315   40000000    120.0
# 2086   358991681   18000000    120.0
# 2666   377910544   15000000    120.0
# 127    378858340  150000000    120.0
# 91     389681935  165000000    120.0
# 1102   232324128   44500000    120.0
# 2912   775398007   11000000    121.0
# 159    821708551  139000000    121.0
# 299    336529144  100000000    121.0
# 94     773328629  170000000    121.0
# 397    219103655   85000000    121.0
# ...

# %%
# last_500_movies
average_runtime = last_500_movies['runtime'].mean()

# Select movies with runtimes above the average
above_average_movies = last_500_movies[last_500_movies['runtime'] > average_runtime]

# Sort the result in ascending order by runtime
above_average_movies_sorted = above_average_movies.sort_values(by='runtime').head(50)

# Display the names and runtimes of above-average movies
movie_names_runtimes = above_average_movies_sorted[['revenue','budget','runtime']]
display(movie_names_runtimes)
# Out:
#       revenue    budget  runtime
# 4268  3897569   1350000    105.0
# 3881  5332926   3200000    105.0
# 4604  4500000    325000    105.0
# 2275  5496951  27220000    105.0
# 4017  5535405   2500000    105.0
# 2641   632542  15000000    105.0
# 4002  3166000   2600000    105.0
# 2622  5217498  15000000    105.0
# 3838  6451628  10000000    105.0
# 3088  1969193  20000000    105.0
# 2389  1831348  18000000    105.0
# 3224  6108720   9000000    106.0
# 3098  1296184   5000000    106.0
# 3388  1429299   7000000    106.0
# 4382   274661   1000000    106.0
# 3279   589304   8000000    106.0
# 2233  6420319  20000000    106.0
# 1295  6614280  39000000    106.0
# 2620  8138788  15000000    106.0
# 3160  2995811  10000000    106.0
# 4094  4000000   2000000    106.0
# 3390   382946   7000000    106.0
# 3816  8000000   3768785    107.0
# 3494   869325   6000000    107.0
# 2264  4634062  20000000    107.0
# 4485  4911725    700000    107.0
# 4443   819939    850000    107.0
# ...

# %% [markdown]
# As we can see as the result the top_500_ movies are having above average runtime giving the good revenue output with the good budget.In the other result of the last_500_movies giving the low out where the budget is high.

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# The high budget movies giving the high revenue. Production companies are spending more on the popular movies.Also some popular movies are running for long time in compare to the non-popular movies. It also depends on the movie genre where public shows interest and expect the more runtime but the otherside it is not very clear that the rating of the movie is depend on the popularity.People may have different taste and interest.They need to icrease their budget on good graphics,on actors ,movie marketing like banners and teasers to atract public in the cinemas and also more need to increase their runtime according to the genres.
